# %%
import os
import re
import requests
from bs4 import BeautifulSoup
from urllib.parse import urljoin
import urllib.request
import time

# %%
base_url = "https://www.handspeak.com/word/"
output_folder = "asl_videos"
os.makedirs(output_folder, exist_ok=True)

# Get the index page
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/124.0.0.0 Safari/537.36"
}

response = requests.get(base_url, headers=headers)
soup = BeautifulSoup(response.content, 'html.parser')

# %%
# Step 1: Get all word page links
# Find all <a> tags with href like "/word/1234"
word_links = soup.find_all("a", href=re.compile(r"^/word/\d+"))

# %%
len(word_links)
# Out:
# 315

# %%
# Find all <a> tags with href like "/word/1234"
word_links = soup.find_all("a", href=re.compile(r"^/word/\d+"))

print(f"Found {len(word_links)} links")
for link in word_links[:5]:  # Show a few examples
    print(f"{link.get_text(strip=True)} -> {link['href']}")
# Out:
# Found 315 links
# about -> /word/6/
# again -> /word/51/
# ask -> /word/117/
# bad -> /word/150/
# boy -> /word/223/

# %%
# Step 2: Visit each word page and download the 2nd video
for link in word_links:
    relative_url = link['href']
    full_url = urljoin(base_url, relative_url)

    if full_url in seen:
        continue
    seen.add(full_url)

    try:
        word_page = requests.get(full_url, headers=headers)
        word_soup = BeautifulSoup(word_page.content, 'html.parser')

        # Get word name from <h1> or <title>
        heading = word_soup.find("h1") or word_soup.find("title")
        word_name = heading.get_text(strip=True).lower().replace(" ", "_") if heading else "unknown"

        # Find the second video with class 'v-asl'
        video_tags = word_soup.find_all("video", class_="v-asl")
        if len(video_tags) < 2:
            print(f"❌ Less than 2 .v-asl videos for {word_name} ({full_url})")
            continue

        video_tag = video_tags[1]
        video_url = video_tag.get('src')

        if not video_url:
            print(f"❌ No src found for video on {full_url}")
            continue

        video_url = urljoin(full_url, video_url)
        video_path = os.path.join(output_folder, f"{word_name}.mp4")

        # Download video using spoofed headers
        video_headers = {
            "User-Agent": headers["User-Agent"],
            "Referer": full_url
        }

        video_response = requests.get(video_url, headers=video_headers, stream=True)
        if video_response.status_code == 200:
            with open(video_path, "wb") as f:
                for chunk in video_response.iter_content(chunk_size=8192):
                    f.write(chunk)
            print(f"✅ Downloaded: {word_name}")
        else:
            print(f"❌ Failed to download {word_name} (status code: {video_response.status_code})")

        time.sleep(0.5)  # Be kind to the server

    except Exception as e:
        print(f"⚠️ Error processing {full_url}: {e}")
# Out:
# ❌ Less than 2 .v-asl videos for can_in_sign_language (https://www.handspeak.com/word/307/)
# ✅ Downloaded: come_in_sign_language
# ✅ Downloaded: deaf_in_sign_language
# ✅ Downloaded: different_in_sign_language
# ✅ Downloaded: drink_in_sign_language
# ✅ Downloaded: eat_in_sign_language
# ✅ Downloaded: family_in_sign_language
# ❌ Less than 2 .v-asl videos for feel_in_sign_language (https://www.handspeak.com/word/768/)
# ✅ Downloaded: few_in_sign_language
# ❌ Less than 2 .v-asl videos for find_in_sign_language (https://www.handspeak.com/word/2746/)
# ✅ Downloaded: fine_in_sign_language
# ✅ Downloaded: finish_in_sign_language
# ✅ Downloaded: for_in_sign_language
# ✅ Downloaded: forget_in_sign_language
# ✅ Downloaded: friend_in_sign_language
# ❌ Less than 2 .v-asl videos for get_in_sign_language (https://www.handspeak.com/word/901/)
# ✅ Downloaded: girl_in_sign_language
# ✅ Downloaded: give_in_sign_language
# ✅ Downloaded: go,_went_in_sign_language
# ⚠️ Error processing https://www.handspeak.com/word/926/: [Errno 22] Invalid argument: 'asl_videos\\"good"_in_sign_language.mp4'
# ✅ Downloaded: happy_in_sign_language
# ✅ Downloaded: have,_has,_had_in_sign_language
# ❌ Less than 2 .v-asl videos for he_in_sign_language (https://www.handspeak.com/word/1671/)
# ✅ Downloaded: hearing_in_sign_language
# ✅ Downloaded: hello_in_sign_language
# ✅ Downloaded: help_in_sign_language
# ❌ Less than 2 .v-asl videos for home_in_sign_language (https://www.handspeak.com/word/1046/)
# ✅ Downloaded: how_in_sign_language
# ✅ Downloaded: internet_in_sign_language
# ✅ Downloaded: know_in_sign_language
# ✅ Downloaded: later_in_sign_language
# ❌ Less than 2 .v-asl videos for like_in_sign_language (https://www.handspeak.com/word/1276/)
# ✅ Downloaded: little_in_sign_language
# ✅ Downloaded: live_in_sign_language
# ✅ Downloaded: look_in_sign_language
# ❌ Less than 2 .v-asl videos for make_in_sign_language (https://www.handspeak.com/word/1331/)
# ✅ Downloaded: man_in_sign_language
# ✅ Downloaded: many_in_sign_language
# ❌ Less than 2 .v-asl videos for me_in_sign_language (https://www.handspeak.com/word/1363/)
# ✅ Downloaded: meet_in_sign_language
# ✅ Downloaded: more_in_sign_language
# ❌ Less than 2 .v-asl videos for my_in_sign_language (https://www.handspeak.com/word/1448/)
# ✅ Downloaded: name_in_sign_language
# ❌ Less than 2 .v-asl videos for need_in_sign_language (https://www.handspeak.com/word/1471/)
# ✅ Downloaded: new_in_sign_language
# ⚠️ Error processing https://www.handspeak.com/word/1496/: [Errno 22] Invalid argument: 'asl_videos\\"no"_in_sign_language.mp4'
# ❌ Less than 2 .v-asl videos for not_in_sign_language (https://www.handspeak.com/word/1515/)
# ✅ Downloaded: now_in_sign_language
# ❌ Less than 2 .v-asl videos for okay_in_sign_language (https://www.handspeak.com/word/1545/)
# ✅ Downloaded: old_in_sign_language
# ✅ Downloaded: other,_another_in_sign_language
# ❌ Less than 2 .v-asl videos for please_in_sign_language (https://www.handspeak.com/word/1658/)
# ✅ Downloaded: remember_in_sign_language
# ❌ Less than 2 .v-asl videos for sad_in_sign_language (https://www.handspeak.com/word/1866/)
# ✅ Downloaded: same_in_sign_language
# ❌ Less than 2 .v-asl videos for signs_for_say (https://www.handspeak.com/word/1881/)
# ❌ Less than 2 .v-asl videos for school_in_sign_language (https://www.handspeak.com/word/1889/)
# ❌ Less than 2 .v-asl videos for "see"_in_sign_language (https://www.handspeak.com/word/1911/)
# ❌ Less than 2 .v-asl videos for she_in_sign_language (https://www.handspeak.com/word/1670/)
# ✅ Downloaded: sign_(word)_in_sign_language
# ❌ Less than 2 .v-asl videos for slow_in_sign_language (https://www.handspeak.com/word/1992/)
# ❌ Less than 2 .v-asl videos for some_in_sign_language (https://www.handspeak.com/word/2019/)
# ❌ Less than 2 .v-asl videos for sorry_in_sign_language (https://www.handspeak.com/word/2027/)
# ✅ Downloaded: stay_in_sign_language
# ✅ Downloaded: take_in_sign_language
# ✅ Downloaded: talk_in_sign_language
# ✅ Downloaded: tell_in_sign_language
# ✅ Downloaded: thank_you_in_sign_language
# ❌ Less than 2 .v-asl videos for signs_for_their (https://www.handspeak.com/word/2715/)
# ✅ Downloaded: they_in_sign_language
# ❌ Less than 2 .v-asl videos for thing_in_sign_language (https://www.handspeak.com/word/2200/)
# ❌ Less than 2 .v-asl videos for think_in_sign_language (https://www.handspeak.com/word/2201/)
# ✅ Downloaded: time_in_sign_language
# ❌ Less than 2 .v-asl videos for tired_in_sign_language (https://www.handspeak.com/word/2225/)
# ❌ Less than 2 .v-asl videos for try_in_sign_language (https://www.handspeak.com/word/2272/)
# ✅ Downloaded: understand_in_sign_language
# ✅ Downloaded: use_in_sign_language
# ✅ Downloaded: wait_in_sign_language
# ❌ Less than 2 .v-asl videos for want_in_sign_language (https://www.handspeak.com/word/2347/)
# ✅ Downloaded: what_in_sign_language
# ✅ Downloaded: when_in_sign_language
# ✅ Downloaded: where_in_sign_language
# ❌ Less than 2 .v-asl videos for which_in_sign_language (https://www.handspeak.com/word/2393/)
# ✅ Downloaded: who_in_sign_language
# ✅ Downloaded: why_in_sign_language
# ❌ Less than 2 .v-asl videos for will_in_sign_language (https://www.handspeak.com/word/2401/)
# ❌ Less than 2 .v-asl videos for with_in_sign_language (https://www.handspeak.com/word/2412/)
# ✅ Downloaded: woman_in_sign_language
# ✅ Downloaded: work_in_sign_language
# ✅ Downloaded: write_in_sign_language
# ✅ Downloaded: yes_in_sign_language
# ❌ Less than 2 .v-asl videos for you_in_sign_language (https://www.handspeak.com/word/2448/)
# ✅ Downloaded: your_in_sign_language
# ❌ Less than 2 .v-asl videos for after_sign_language (https://www.handspeak.com/word/49/)
# ✅ Downloaded: all_in_sign_language
# ❌ Less than 2 .v-asl videos for 'answer'_in_sign_language (https://www.handspeak.com/word/90/)
# ❌ Less than 2 .v-asl videos for any_in_sign_language (https://www.handspeak.com/word/91/)
# ✅ Downloaded: arrive_in_sign_language
# ❌ Less than 2 .v-asl videos for beautiful_in_sign_language (https://www.handspeak.com/word/171/)
# ✅ Downloaded: because_in_sign_language
# ✅ Downloaded: before_in_sign_language
# ❌ Less than 2 .v-asl videos for better_in_sign_language (https://www.handspeak.com/word/189/)
# ✅ Downloaded: big_in_sign_language
# ✅ Downloaded: bring_in_sign_language
# ✅ Downloaded: busy_in_sign_language
# ✅ Downloaded: change_in_sign_language
# ✅ Downloaded: clean_sign_language
# ✅ Downloaded: close_in_sign_language
# ❌ Less than 2 .v-asl videos for signs_for_cold (https://www.handspeak.com/word/416/)
# ✅ Downloaded: color_in_sign_language
# ✅ Downloaded: day_in_sign_language
# ✅ Downloaded: drive_in_sign_language
# ✅ Downloaded: early_in_sign_language
# ❌ Less than 2 .v-asl videos for easy_in_sign_language (https://www.handspeak.com/word/644/)
# ✅ Downloaded: email_in_sign_language
# ✅ Downloaded: enough_in_sign_language
# ❌ Less than 2 .v-asl videos for every_in_sign_language (https://www.handspeak.com/word/695/)
# ✅ Downloaded: excuse_in_sign_language
# ✅ Downloaded: false_in_sign_language
# ❌ Less than 2 .v-asl videos for far_in_sign_language (https://www.handspeak.com/word/743/)
# ✅ Downloaded: fast_in_sign_language
# ✅ Downloaded: fingerspell_in_sign_language
# ❌ Less than 2 .v-asl videos for follow_in_sign_language (https://www.handspeak.com/word/835/)
# ✅ Downloaded: food_in_sign_language
# ❌ Less than 2 .v-asl videos for from_in_sign_language (https://www.handspeak.com/word/870/)
# ✅ Downloaded: gone_in_sign_language
# ❌ Less than 2 .v-asl videos for happen_in_sign_language (https://www.handspeak.com/word/984/)
# ✅ Downloaded: hard_in_sign_language
# ✅ Downloaded: here_in_sign_language
# ✅ Downloaded: hot_in_sign_language
# ✅ Downloaded: hurt_in_sign_language
# ✅ Downloaded: improve_in_sign_language
# ❌ Less than 2 .v-asl videos for "in"_in_sign_language (https://www.handspeak.com/word/1112/)
# ❌ Less than 2 .v-asl videos for inform_in_sign_language (https://www.handspeak.com/word/1121/)
# ✅ Downloaded: keep_in_sign_language
# ✅ Downloaded: last_in_sign_language
# ❌ Less than 2 .v-asl videos for late_in_sign_language (https://www.handspeak.com/word/1236/)
# ✅ Downloaded: learn_in_sign_language
# ✅ Downloaded: leave_in_sign_language
# ❌ Less than 2 .v-asl videos for signs_for_look_for (https://www.handspeak.com/word/1306/)
# ✅ Downloaded: signs_for_lot,_a_lot
# ❌ Less than 2 .v-asl videos for mean,_meaning_in_sign_language (https://www.handspeak.com/word/1364/)
# ❌ Less than 2 .v-asl videos for minute_in_sign_language (https://www.handspeak.com/word/1392/)
# ✅ Downloaded: month_in_sign_language
# ✅ Downloaded: morning_in_sign_language
# ❌ Less than 2 .v-asl videos for most_in_sign_language (https://www.handspeak.com/word/1438/)
# ✅ Downloaded: must_in_sign_language
# ✅ Downloaded: near_in_sign_language
# ✅ Downloaded: never_in_sign_language
# ✅ Downloaded: next_in_sign_language
# ✅ Downloaded: night_in_sign_language
# ✅ Downloaded: nothing_in_sign_language
# ❌ Less than 2 .v-asl videos for signs_for_only (https://www.handspeak.com/word/1560/)
# ✅ Downloaded: open_in_sign_language
# ❌ Less than 2 .v-asl videos for opposite_in_sign_language (https://www.handspeak.com/word/1565/)
# ✅ Downloaded: out_in_sign_language
# ✅ Downloaded: people_in_sign_language
# ✅ Downloaded: plan_in_sign_language
# ✅ Downloaded: practice_in_sign_language
# ❌ Less than 2 .v-asl videos for signs_for_prefer (https://www.handspeak.com/word/1699/)
# ✅ Downloaded: question_in_sign_language
# ✅ Downloaded: read_in_sign_language
# ✅ Downloaded: ready_in_sign_language
# ❌ Less than 2 .v-asl videos for rest_in_sign_language (https://www.handspeak.com/word/1812/)
# ✅ Downloaded: right_in_sign_language
# ✅ Downloaded: run_in_sign_language
# ✅ Downloaded: send_in_sign_language
# ❌ Less than 2 .v-asl videos for should_in_sign_language (https://www.handspeak.com/word/1952/)
# ✅ Downloaded: show_in_sign_language
# ✅ Downloaded: sit_in_sign_language
# ❌ Less than 2 .v-asl videos for sleep_in_sign_language (https://www.handspeak.com/word/1985/)
# ✅ Downloaded: small_in_sign_language
# ❌ Less than 2 .v-asl videos for something_in_sign_language (https://www.handspeak.com/word/2020/)
# ❌ Less than 2 .v-asl videos for sometimes_in_sign_language (https://www.handspeak.com/word/2021/)
# ✅ Downloaded: start_in_sign_language
# ❌ Less than 2 .v-asl videos for still_in_sign_language (https://www.handspeak.com/word/2076/)
# ❌ Less than 2 .v-asl videos for stop_in_sign_language (https://www.handspeak.com/word/2079/)
# ✅ Downloaded: signs_for_store
# ❌ Less than 2 .v-asl videos for support_in_sign_language (https://www.handspeak.com/word/2124/)
# ✅ Downloaded: teach_in_sign_language
# ❌ Less than 2 .v-asl videos for signs_for_than (https://www.handspeak.com/word/2185/)
# ✅ Downloaded: today_in_sign_language
# ❌ Less than 2 .v-asl videos for toilet_in_sign_language (https://www.handspeak.com/word/2230/)
# ❌ Less than 2 .v-asl videos for tomorrow_in_sign_language (https://www.handspeak.com/word/2233/)
# ❌ Less than 2 .v-asl videos for true_in_sign_language (https://www.handspeak.com/word/2269/)
# ❌ Less than 2 .v-asl videos for until_in_sign_language (https://www.handspeak.com/word/2299/)
# ✅ Downloaded: visit_in_sign_language
# ✅ Downloaded: walk_in_sign_language
# ✅ Downloaded: warm_in_sign_language
# ✅ Downloaded: watch_in_sign_language
# ✅ Downloaded: worse_in_sign_language
# ✅ Downloaded: wrong_in_sign_language
# ❌ Less than 2 .v-asl videos for yesterday_in_sign_language (https://www.handspeak.com/word/2444/)
# ❌ Less than 2 .v-asl videos for accept_in_sign_language (https://www.handspeak.com/word/10/)
# ✅ Downloaded: afternoon_in_sign_language
# ❌ Less than 2 .v-asl videos for against_in_sign_language (https://www.handspeak.com/word/52/)
# ✅ Downloaded: agree_in_sign_language
# ❌ Less than 2 .v-asl videos for allow_in_sign_language (https://www.handspeak.com/word/65/)
# ❌ Less than 2 .v-asl videos for signs_for_almost (https://www.handspeak.com/word/66/)
# ✅ Downloaded: alone_in_sign_language
# ❌ Less than 2 .v-asl videos for always_in_sign_language (https://www.handspeak.com/word/71/)
# ❌ Less than 2 .v-asl videos for and_in_sign_language (https://www.handspeak.com/word/79/)
# ❌ Less than 2 .v-asl videos for angry_in_sign_language (https://www.handspeak.com/word/81/)
# ❌ Less than 2 .v-asl videos for animal_in_sign_language (https://www.handspeak.com/word/82/)
# ❌ Less than 2 .v-asl videos for anything_in_sign_language (https://www.handspeak.com/word/92/)
# ✅ Downloaded: argue,_argument_in_sign_language
# ❌ Less than 2 .v-asl videos for asl_/_american_sign_language_/_ameslan (https://www.handspeak.com/word/120/)
# ❌ Less than 2 .v-asl videos for attitude_in_sign_language (https://www.handspeak.com/word/128/)
# ❌ Less than 2 .v-asl videos for autumn_in_sign_language (https://www.handspeak.com/word/2777/)
# ✅ Downloaded: signs_for_average
# ❌ Less than 2 .v-asl videos for avoid_in_sign_language (https://www.handspeak.com/word/141/)
# ✅ Downloaded: away_in_sign_language
# ❌ Less than 2 .v-asl videos for signs_for_basic (https://www.handspeak.com/word/158/)
# ❌ Less than 2 .v-asl videos for believe_in_sign_language (https://www.handspeak.com/word/183/)
# ❌ Less than 2 .v-asl videos for signs_for_best (https://www.handspeak.com/word/188/)
# ✅ Downloaded: book_in_sign_language
# ✅ Downloaded: both_in_sign_language
# ✅ Downloaded: brother_in_sign_language
# ✅ Downloaded: signs_for_calm
# ✅ Downloaded: car_in_sign_language
# ❌ Less than 2 .v-asl videos for class_in_sign_language (https://www.handspeak.com/word/398/)
# ✅ Downloaded: signs_for_close,_close-by,_close_to
# ❌ Less than 2 .v-asl videos for comfortable_in_sign_language (https://www.handspeak.com/word/426/)
# ❌ Less than 2 .v-asl videos for deep_in_sign_language (https://www.handspeak.com/word/3249/)
# ✅ Downloaded: doubt_in_sign_language
# ✅ Downloaded: english_in_sign_language
# ❌ Less than 2 .v-asl videos for signs_for_everyday (https://www.handspeak.com/word/696/)
# ❌ Less than 2 .v-asl videos for signs_for_everything (https://www.handspeak.com/word/697/)
# ✅ Downloaded: example_in_sign_language
# ✅ Downloaded: father_in_sign_language
# ✅ Downloaded: funny_in_sign_language
# ❌ Less than 2 .v-asl videos for asl_signs_for_game (https://www.handspeak.com/word/889/)
# ✅ Downloaded: gift_in_sign_language
# ✅ Downloaded: grow_in_sign_language
# ❌ Less than 2 .v-asl videos for signs_for_guess (https://www.handspeak.com/word/953/)
# ✅ Downloaded: hear_in_sign_language
# ✅ Downloaded: hold_in_sign_language
# ✅ Downloaded: house_in_sign_language
# ✅ Downloaded: idea_in_sign_language
# ✅ Downloaded: if_in_sign_language
# ❌ Less than 2 .v-asl videos for important_in_sign_language (https://www.handspeak.com/word/1106/)
# ❌ Less than 2 .v-asl videos for include_in_sign_language (https://www.handspeak.com/word/1113/)
# ❌ Less than 2 .v-asl videos for signs_for_interpreter (https://www.handspeak.com/word/1148/)
# ✅ Downloaded: joke_in_sign_language
# ✅ Downloaded: letter_in_sign_language
# ❌ Less than 2 .v-asl videos for signs_for_life (https://www.handspeak.com/word/323/)
# ✅ Downloaded: signs_for_look_like
# ✅ Downloaded: lose,_lost_in_sign_language
# ✅ Downloaded: love_in_sign_language
# ❌ Less than 2 .v-asl videos for money_in_sign_language (https://www.handspeak.com/word/1409/)
# ✅ Downloaded: mother_in_sign_language
# ✅ Downloaded: move_in_sign_language
# ❌ Less than 2 .v-asl videos for movie_in_sign_language (https://www.handspeak.com/word/1453/)
# ❌ Less than 2 .v-asl videos for signs_for_normal (https://www.handspeak.com/word/1502/)
# ❌ Less than 2 .v-asl videos for number_in_sign_language (https://www.handspeak.com/word/1526/)
# ❌ Less than 2 .v-asl videos for signs_for_offspring (https://www.handspeak.com/word/384/)
# ✅ Downloaded: outside_in_sign_language
# ❌ Less than 2 .v-asl videos for signs_for_overlook (https://www.handspeak.com/word/1587/)
# ✅ Downloaded: paper_in_sign_language
# ✅ Downloaded: party_in_sign_language
# ✅ Downloaded: pay_in_sign_language
# ✅ Downloaded: pen_in_sign_language
# ✅ Downloaded: picture_in_sign_language
# ❌ Less than 2 .v-asl videos for play_in_sign_language (https://www.handspeak.com/word/1657/)
# ❌ Less than 2 .v-asl videos for signs_for_problem (https://www.handspeak.com/word/1721/)
# ❌ Less than 2 .v-asl videos for room_in_sign_language (https://www.handspeak.com/word/1848/)
# ❌ Less than 2 .v-asl videos for safe_in_sign_language (https://www.handspeak.com/word/5045/)
# ✅ Downloaded: sell_in_sign_language
# ❌ Less than 2 .v-asl videos for signs_for_service (https://www.handspeak.com/word/1927/)
# ❌ Less than 2 .v-asl videos for signs_for_share (https://www.handspeak.com/word/1934/)
# ✅ Downloaded: sick_in_sign_language
# ✅ Downloaded: since_in_sign_language
# ✅ Downloaded: sister_in_sign_language
# ❌ Less than 2 .v-asl videos for smart_in_sign_language (https://www.handspeak.com/word/1994/)
# ✅ Downloaded: signs_for_soon
# ❌ Less than 2 .v-asl videos for spring_in_sign_language (https://www.handspeak.com/word/2055/)
# ✅ Downloaded: story_in_sign_language
# ❌ Less than 2 .v-asl videos for struggle_in_sign_language (https://www.handspeak.com/word/2097/)
# ✅ Downloaded: study_in_sign_language
# ❌ Less than 2 .v-asl videos for summer_in_sign_language (https://www.handspeak.com/word/2113/)
# ✅ Downloaded: sure_in_sign_language
# ✅ Downloaded: that_in_sign_language
# ❌ Less than 2 .v-asl videos for travel_in_sign_language (https://www.handspeak.com/word/2262/)
# ✅ Downloaded: wash_in_sign_language
# ❌ Less than 2 .v-asl videos for water_in_sign_language (https://www.handspeak.com/word/2360/)
# ✅ Downloaded: week_in_sign_language
# ❌ Less than 2 .v-asl videos for signs_for_weekend (https://www.handspeak.com/word/2371/)
# ✅ Downloaded: winter_in_sign_language
# ❌ Less than 2 .v-asl videos for wish_in_sign_language (https://www.handspeak.com/word/2410/)
# ✅ Downloaded: word_in_sign_language
# ✅ Downloaded: signs_for_yet,_not_yet
# ❌ Less than 2 .v-asl videos for young_in_sign_language (https://www.handspeak.com/word/2452/)
# ✅ Downloaded: yourself_in_sign_language
# ❌ Less than 2 .v-asl videos for mirror_in_sign_language (https://www.handspeak.com/word/1393/)
# ❌ Less than 2 .v-asl videos for signs_for_april_fool (https://www.handspeak.com/word/6381/)
# ✅ Downloaded: tax_in_sign_language
# ✅ Downloaded: easter_in_sign_language
# ✅ Downloaded: signs_for_condone
# ✅ Downloaded: welcome_in_sign_language
# ✅ Downloaded: sentence_in_sign_language
# ✅ Downloaded: context_in_sign_language

# %% [markdown]
# Download videos missed in initial scrape

# %%
# Get already downloaded words (without .mp4)
downloaded_words = {
    os.path.splitext(f)[0] for f in os.listdir(output_folder) if f.endswith(".mp4")
}
print(f"📂 Found {len(downloaded_words)} videos already downloaded.")
# Out:
# 📂 Found 181 videos already downloaded.

# %%
seen = set()

# Step 2: Process each word page
for link in word_links:
    relative_url = link['href']
    full_url = urljoin(base_url, relative_url)

    if full_url in seen:
        continue
    seen.add(full_url)

    try:
        word_page = requests.get(full_url, headers=headers)
        word_soup = BeautifulSoup(word_page.content, 'html.parser')

        # Extract the word name
        heading = word_soup.find("h1") or word_soup.find("title")
        word_name = heading.get_text(strip=True).lower().replace(" ", "_") if heading else "unknown"

        # Skip if already downloaded
        if word_name in downloaded_words:
            print(f"⏩ Skipping already downloaded: {word_name}")
            continue

        # Find video tags
        video_tags = word_soup.find_all("video", class_="v-asl")

        video_tag = None
        if len(video_tags) >= 2:
            video_tag = video_tags[1]
        elif len(video_tags) == 1:
            video_tag = video_tags[0]
            print(f"⚠️ Only one video for {word_name}, using fallback.")

        if not video_tag:
            print(f"❌ No usable video tag for {word_name}")
            continue

        # Get video URL
        video_url = video_tag.get("src")
        if not video_url:
            print(f"❌ No src attribute for video tag of {word_name}")
            continue

        video_url = urljoin(full_url, video_url)
        video_path = os.path.join(output_folder, f"{word_name}.mp4")

        # Download with spoofed headers
        video_headers = {
            "User-Agent": headers["User-Agent"],
            "Referer": full_url
        }

        video_response = requests.get(video_url, headers=video_headers, stream=True)
        if video_response.status_code == 200:
            with open(video_path, "wb") as f:
                for chunk in video_response.iter_content(chunk_size=8192):
                    f.write(chunk)
            print(f"✅ Downloaded: {word_name}")
        else:
            print(f"❌ Failed to download {word_name} (status code: {video_response.status_code})")

        time.sleep(0.5)

    except Exception as e:
        print(f"⚠️ Error processing {full_url}: {e}")
# Out:
# ✅ Downloaded: about_in_sign_language
# ⚠️ Only one video for again_in_sign_language, using fallback.
# ✅ Downloaded: again_in_sign_language
# ✅ Downloaded: ask_in_sign_language
# ⚠️ Only one video for bad_in_sign_language, using fallback.
# ✅ Downloaded: bad_in_sign_language
# ✅ Downloaded: boy_in_sign_language
# ✅ Downloaded: but_in_sign_language
# ⚠️ Only one video for buy_in_sign_language, using fallback.
# ✅ Downloaded: buy_in_sign_language
# ⚠️ Only one video for can_in_sign_language, using fallback.
# ✅ Downloaded: can_in_sign_language
# ⏩ Skipping already downloaded: come_in_sign_language
# ⏩ Skipping already downloaded: deaf_in_sign_language
# ⏩ Skipping already downloaded: different_in_sign_language
# ⏩ Skipping already downloaded: drink_in_sign_language
# ⏩ Skipping already downloaded: eat_in_sign_language
# ⏩ Skipping already downloaded: family_in_sign_language
# ⚠️ Only one video for feel_in_sign_language, using fallback.
# ✅ Downloaded: feel_in_sign_language
# ⏩ Skipping already downloaded: few_in_sign_language
# ⚠️ Only one video for find_in_sign_language, using fallback.
# ✅ Downloaded: find_in_sign_language
# ⏩ Skipping already downloaded: fine_in_sign_language
# ⏩ Skipping already downloaded: finish_in_sign_language
# ⏩ Skipping already downloaded: for_in_sign_language
# ⏩ Skipping already downloaded: forget_in_sign_language
# ⏩ Skipping already downloaded: friend_in_sign_language
# ⚠️ Only one video for get_in_sign_language, using fallback.
# ✅ Downloaded: get_in_sign_language
# ⏩ Skipping already downloaded: girl_in_sign_language
# ⏩ Skipping already downloaded: give_in_sign_language
# ⏩ Skipping already downloaded: go,_went_in_sign_language
# ⚠️ Error processing https://www.handspeak.com/word/926/: [Errno 22] Invalid argument: 'asl_videos\\"good"_in_sign_language.mp4'
# ⏩ Skipping already downloaded: happy_in_sign_language
# ⏩ Skipping already downloaded: have,_has,_had_in_sign_language
# ⚠️ Only one video for he_in_sign_language, using fallback.
# ✅ Downloaded: he_in_sign_language
# ⏩ Skipping already downloaded: hearing_in_sign_language
# ⏩ Skipping already downloaded: hello_in_sign_language
# ⏩ Skipping already downloaded: help_in_sign_language
# ⚠️ Only one video for home_in_sign_language, using fallback.
# ✅ Downloaded: home_in_sign_language
# ⏩ Skipping already downloaded: how_in_sign_language
# ⏩ Skipping already downloaded: internet_in_sign_language
# ⏩ Skipping already downloaded: know_in_sign_language
# ⏩ Skipping already downloaded: later_in_sign_language
# ⚠️ Only one video for like_in_sign_language, using fallback.
# ✅ Downloaded: like_in_sign_language
# ⏩ Skipping already downloaded: little_in_sign_language
# ⏩ Skipping already downloaded: live_in_sign_language
# ⏩ Skipping already downloaded: look_in_sign_language
# ⚠️ Only one video for make_in_sign_language, using fallback.
# ✅ Downloaded: make_in_sign_language
# ⏩ Skipping already downloaded: man_in_sign_language
# ⏩ Skipping already downloaded: many_in_sign_language
# ⚠️ Only one video for me_in_sign_language, using fallback.
# ✅ Downloaded: me_in_sign_language
# ⏩ Skipping already downloaded: meet_in_sign_language
# ⏩ Skipping already downloaded: more_in_sign_language
# ⚠️ Only one video for my_in_sign_language, using fallback.
# ✅ Downloaded: my_in_sign_language
# ⏩ Skipping already downloaded: name_in_sign_language
# ⚠️ Only one video for need_in_sign_language, using fallback.
# ✅ Downloaded: need_in_sign_language
# ⏩ Skipping already downloaded: new_in_sign_language
# ⚠️ Error processing https://www.handspeak.com/word/1496/: [Errno 22] Invalid argument: 'asl_videos\\"no"_in_sign_language.mp4'
# ⚠️ Only one video for not_in_sign_language, using fallback.
# ✅ Downloaded: not_in_sign_language
# ⏩ Skipping already downloaded: now_in_sign_language
# ⚠️ Only one video for okay_in_sign_language, using fallback.
# ✅ Downloaded: okay_in_sign_language
# ⏩ Skipping already downloaded: old_in_sign_language
# ⏩ Skipping already downloaded: other,_another_in_sign_language
# ⚠️ Only one video for please_in_sign_language, using fallback.
# ✅ Downloaded: please_in_sign_language
# ⏩ Skipping already downloaded: remember_in_sign_language
# ⚠️ Only one video for sad_in_sign_language, using fallback.
# ✅ Downloaded: sad_in_sign_language
# ⏩ Skipping already downloaded: same_in_sign_language
# ⚠️ Only one video for signs_for_say, using fallback.
# ✅ Downloaded: signs_for_say
# ⚠️ Only one video for school_in_sign_language, using fallback.
# ✅ Downloaded: school_in_sign_language
# ⚠️ Only one video for "see"_in_sign_language, using fallback.
# ⚠️ Error processing https://www.handspeak.com/word/1911/: [Errno 22] Invalid argument: 'asl_videos\\"see"_in_sign_language.mp4'
# ⚠️ Only one video for she_in_sign_language, using fallback.
# ✅ Downloaded: she_in_sign_language
# ⏩ Skipping already downloaded: sign_(word)_in_sign_language
# ⚠️ Only one video for slow_in_sign_language, using fallback.
# ✅ Downloaded: slow_in_sign_language
# ⚠️ Only one video for some_in_sign_language, using fallback.
# ✅ Downloaded: some_in_sign_language
# ⚠️ Only one video for sorry_in_sign_language, using fallback.
# ✅ Downloaded: sorry_in_sign_language
# ⏩ Skipping already downloaded: stay_in_sign_language
# ⏩ Skipping already downloaded: take_in_sign_language
# ⏩ Skipping already downloaded: talk_in_sign_language
# ⏩ Skipping already downloaded: tell_in_sign_language
# ⏩ Skipping already downloaded: thank_you_in_sign_language
# ⚠️ Only one video for signs_for_their, using fallback.
# ✅ Downloaded: signs_for_their
# ⏩ Skipping already downloaded: they_in_sign_language
# ⚠️ Only one video for thing_in_sign_language, using fallback.
# ✅ Downloaded: thing_in_sign_language
# ⚠️ Only one video for think_in_sign_language, using fallback.
# ✅ Downloaded: think_in_sign_language
# ⏩ Skipping already downloaded: time_in_sign_language
# ⚠️ Only one video for tired_in_sign_language, using fallback.
# ✅ Downloaded: tired_in_sign_language
# ⚠️ Only one video for try_in_sign_language, using fallback.
# ✅ Downloaded: try_in_sign_language
# ⏩ Skipping already downloaded: understand_in_sign_language
# ⏩ Skipping already downloaded: use_in_sign_language
# ⏩ Skipping already downloaded: wait_in_sign_language
# ⚠️ Only one video for want_in_sign_language, using fallback.
# ✅ Downloaded: want_in_sign_language
# ⏩ Skipping already downloaded: what_in_sign_language
# ⏩ Skipping already downloaded: when_in_sign_language
# ⏩ Skipping already downloaded: where_in_sign_language
# ⚠️ Only one video for which_in_sign_language, using fallback.
# ✅ Downloaded: which_in_sign_language
# ⏩ Skipping already downloaded: who_in_sign_language
# ⏩ Skipping already downloaded: why_in_sign_language
# ⚠️ Only one video for will_in_sign_language, using fallback.
# ✅ Downloaded: will_in_sign_language
# ⚠️ Only one video for with_in_sign_language, using fallback.
# ✅ Downloaded: with_in_sign_language
# ⏩ Skipping already downloaded: woman_in_sign_language
# ⏩ Skipping already downloaded: work_in_sign_language
# ⏩ Skipping already downloaded: write_in_sign_language
# ⏩ Skipping already downloaded: yes_in_sign_language
# ⚠️ Only one video for you_in_sign_language, using fallback.
# ✅ Downloaded: you_in_sign_language
# ⏩ Skipping already downloaded: your_in_sign_language
# ⚠️ Only one video for after_sign_language, using fallback.
# ✅ Downloaded: after_sign_language
# ⏩ Skipping already downloaded: all_in_sign_language
# ⚠️ Only one video for 'answer'_in_sign_language, using fallback.
# ✅ Downloaded: 'answer'_in_sign_language
# ⚠️ Only one video for any_in_sign_language, using fallback.
# ✅ Downloaded: any_in_sign_language
# ⏩ Skipping already downloaded: arrive_in_sign_language
# ⚠️ Only one video for beautiful_in_sign_language, using fallback.
# ✅ Downloaded: beautiful_in_sign_language
# ⏩ Skipping already downloaded: because_in_sign_language
# ⏩ Skipping already downloaded: before_in_sign_language
# ⚠️ Only one video for better_in_sign_language, using fallback.
# ✅ Downloaded: better_in_sign_language
# ⏩ Skipping already downloaded: big_in_sign_language
# ⏩ Skipping already downloaded: bring_in_sign_language
# ⏩ Skipping already downloaded: busy_in_sign_language
# ⏩ Skipping already downloaded: change_in_sign_language
# ⏩ Skipping already downloaded: clean_sign_language
# ⏩ Skipping already downloaded: close_in_sign_language
# ⚠️ Only one video for signs_for_cold, using fallback.
# ✅ Downloaded: signs_for_cold
# ⏩ Skipping already downloaded: color_in_sign_language
# ⏩ Skipping already downloaded: day_in_sign_language
# ⏩ Skipping already downloaded: drive_in_sign_language
# ⏩ Skipping already downloaded: early_in_sign_language
# ⚠️ Only one video for easy_in_sign_language, using fallback.
# ✅ Downloaded: easy_in_sign_language
# ⏩ Skipping already downloaded: email_in_sign_language
# ⏩ Skipping already downloaded: enough_in_sign_language
# ⚠️ Only one video for every_in_sign_language, using fallback.
# ✅ Downloaded: every_in_sign_language
# ⏩ Skipping already downloaded: excuse_in_sign_language
# ⏩ Skipping already downloaded: false_in_sign_language
# ⚠️ Only one video for far_in_sign_language, using fallback.
# ✅ Downloaded: far_in_sign_language
# ⏩ Skipping already downloaded: fast_in_sign_language
# ⏩ Skipping already downloaded: fingerspell_in_sign_language
# ⚠️ Only one video for follow_in_sign_language, using fallback.
# ✅ Downloaded: follow_in_sign_language
# ⏩ Skipping already downloaded: food_in_sign_language
# ⚠️ Only one video for from_in_sign_language, using fallback.
# ✅ Downloaded: from_in_sign_language
# ⏩ Skipping already downloaded: gone_in_sign_language
# ⚠️ Only one video for happen_in_sign_language, using fallback.
# ✅ Downloaded: happen_in_sign_language
# ⏩ Skipping already downloaded: hard_in_sign_language
# ⏩ Skipping already downloaded: here_in_sign_language
# ⏩ Skipping already downloaded: hot_in_sign_language
# ⏩ Skipping already downloaded: hurt_in_sign_language
# ⏩ Skipping already downloaded: improve_in_sign_language
# ⚠️ Only one video for "in"_in_sign_language, using fallback.
# ⚠️ Error processing https://www.handspeak.com/word/1112/: [Errno 22] Invalid argument: 'asl_videos\\"in"_in_sign_language.mp4'
# ⚠️ Only one video for inform_in_sign_language, using fallback.
# ✅ Downloaded: inform_in_sign_language
# ⏩ Skipping already downloaded: keep_in_sign_language
# ⏩ Skipping already downloaded: last_in_sign_language
# ⚠️ Only one video for late_in_sign_language, using fallback.
# ✅ Downloaded: late_in_sign_language
# ⏩ Skipping already downloaded: learn_in_sign_language
# ⏩ Skipping already downloaded: leave_in_sign_language
# ⚠️ Only one video for signs_for_look_for, using fallback.
# ✅ Downloaded: signs_for_look_for
# ⏩ Skipping already downloaded: signs_for_lot,_a_lot
# ⚠️ Only one video for mean,_meaning_in_sign_language, using fallback.
# ✅ Downloaded: mean,_meaning_in_sign_language
# ⚠️ Only one video for minute_in_sign_language, using fallback.
# ✅ Downloaded: minute_in_sign_language
# ⏩ Skipping already downloaded: month_in_sign_language
# ⏩ Skipping already downloaded: morning_in_sign_language
# ⚠️ Only one video for most_in_sign_language, using fallback.
# ✅ Downloaded: most_in_sign_language
# ⏩ Skipping already downloaded: must_in_sign_language
# ⏩ Skipping already downloaded: near_in_sign_language
# ⏩ Skipping already downloaded: never_in_sign_language
# ⏩ Skipping already downloaded: next_in_sign_language
# ⏩ Skipping already downloaded: night_in_sign_language
# ⏩ Skipping already downloaded: nothing_in_sign_language
# ⚠️ Only one video for signs_for_only, using fallback.
# ✅ Downloaded: signs_for_only
# ⏩ Skipping already downloaded: open_in_sign_language
# ⚠️ Only one video for opposite_in_sign_language, using fallback.
# ✅ Downloaded: opposite_in_sign_language
# ⏩ Skipping already downloaded: out_in_sign_language
# ⏩ Skipping already downloaded: people_in_sign_language
# ⏩ Skipping already downloaded: plan_in_sign_language
# ⏩ Skipping already downloaded: practice_in_sign_language
# ⚠️ Only one video for signs_for_prefer, using fallback.
# ✅ Downloaded: signs_for_prefer
# ⏩ Skipping already downloaded: question_in_sign_language
# ⏩ Skipping already downloaded: read_in_sign_language
# ⏩ Skipping already downloaded: ready_in_sign_language
# ⚠️ Only one video for rest_in_sign_language, using fallback.
# ✅ Downloaded: rest_in_sign_language
# ⏩ Skipping already downloaded: right_in_sign_language
# ⏩ Skipping already downloaded: run_in_sign_language
# ⏩ Skipping already downloaded: send_in_sign_language
# ⚠️ Only one video for should_in_sign_language, using fallback.
# ✅ Downloaded: should_in_sign_language
# ⏩ Skipping already downloaded: show_in_sign_language
# ⏩ Skipping already downloaded: sit_in_sign_language
# ⚠️ Only one video for sleep_in_sign_language, using fallback.
# ✅ Downloaded: sleep_in_sign_language
# ⏩ Skipping already downloaded: small_in_sign_language
# ⚠️ Only one video for something_in_sign_language, using fallback.
# ✅ Downloaded: something_in_sign_language
# ⚠️ Only one video for sometimes_in_sign_language, using fallback.
# ✅ Downloaded: sometimes_in_sign_language
# ⏩ Skipping already downloaded: start_in_sign_language
# ⚠️ Only one video for still_in_sign_language, using fallback.
# ✅ Downloaded: still_in_sign_language
# ⚠️ Only one video for stop_in_sign_language, using fallback.
# ✅ Downloaded: stop_in_sign_language
# ⏩ Skipping already downloaded: signs_for_store
# ⚠️ Only one video for support_in_sign_language, using fallback.
# ✅ Downloaded: support_in_sign_language
# ⏩ Skipping already downloaded: teach_in_sign_language
# ⚠️ Only one video for signs_for_than, using fallback.
# ✅ Downloaded: signs_for_than
# ⏩ Skipping already downloaded: today_in_sign_language
# ⚠️ Only one video for toilet_in_sign_language, using fallback.
# ✅ Downloaded: toilet_in_sign_language
# ⚠️ Only one video for tomorrow_in_sign_language, using fallback.
# ✅ Downloaded: tomorrow_in_sign_language
# ⚠️ Only one video for true_in_sign_language, using fallback.
# ✅ Downloaded: true_in_sign_language
# ⚠️ Only one video for until_in_sign_language, using fallback.
# ✅ Downloaded: until_in_sign_language
# ⏩ Skipping already downloaded: visit_in_sign_language
# ⏩ Skipping already downloaded: walk_in_sign_language
# ⏩ Skipping already downloaded: warm_in_sign_language
# ⏩ Skipping already downloaded: watch_in_sign_language
# ⏩ Skipping already downloaded: worse_in_sign_language
# ⏩ Skipping already downloaded: wrong_in_sign_language
# ⚠️ Only one video for yesterday_in_sign_language, using fallback.
# ✅ Downloaded: yesterday_in_sign_language
# ⚠️ Only one video for accept_in_sign_language, using fallback.
# ✅ Downloaded: accept_in_sign_language
# ⏩ Skipping already downloaded: afternoon_in_sign_language
# ⚠️ Only one video for against_in_sign_language, using fallback.
# ✅ Downloaded: against_in_sign_language
# ⏩ Skipping already downloaded: agree_in_sign_language
# ⚠️ Only one video for allow_in_sign_language, using fallback.
# ✅ Downloaded: allow_in_sign_language
# ⚠️ Only one video for signs_for_almost, using fallback.
# ✅ Downloaded: signs_for_almost
# ⏩ Skipping already downloaded: alone_in_sign_language
# ⚠️ Only one video for always_in_sign_language, using fallback.
# ✅ Downloaded: always_in_sign_language
# ⚠️ Only one video for and_in_sign_language, using fallback.
# ✅ Downloaded: and_in_sign_language
# ⚠️ Only one video for angry_in_sign_language, using fallback.
# ✅ Downloaded: angry_in_sign_language
# ⚠️ Only one video for animal_in_sign_language, using fallback.
# ✅ Downloaded: animal_in_sign_language
# ⚠️ Only one video for anything_in_sign_language, using fallback.
# ✅ Downloaded: anything_in_sign_language
# ⏩ Skipping already downloaded: argue,_argument_in_sign_language
# ⚠️ Only one video for asl_/_american_sign_language_/_ameslan, using fallback.
# ⚠️ Error processing https://www.handspeak.com/word/120/: [Errno 2] No such file or directory: 'asl_videos\\asl_/_american_sign_language_/_ameslan.mp4'
# ⚠️ Only one video for attitude_in_sign_language, using fallback.
# ✅ Downloaded: attitude_in_sign_language
# ⚠️ Only one video for autumn_in_sign_language, using fallback.
# ✅ Downloaded: autumn_in_sign_language
# ⏩ Skipping already downloaded: signs_for_average
# ⚠️ Only one video for avoid_in_sign_language, using fallback.
# ✅ Downloaded: avoid_in_sign_language
# ⏩ Skipping already downloaded: away_in_sign_language
# ⚠️ Only one video for signs_for_basic, using fallback.
# ✅ Downloaded: signs_for_basic
# ⚠️ Only one video for believe_in_sign_language, using fallback.
# ✅ Downloaded: believe_in_sign_language
# ⚠️ Only one video for signs_for_best, using fallback.
# ✅ Downloaded: signs_for_best
# ⏩ Skipping already downloaded: book_in_sign_language
# ⏩ Skipping already downloaded: both_in_sign_language
# ⏩ Skipping already downloaded: brother_in_sign_language
# ⏩ Skipping already downloaded: signs_for_calm
# ⏩ Skipping already downloaded: car_in_sign_language
# ⚠️ Only one video for class_in_sign_language, using fallback.
# ✅ Downloaded: class_in_sign_language
# ⏩ Skipping already downloaded: signs_for_close,_close-by,_close_to
# ⚠️ Only one video for comfortable_in_sign_language, using fallback.
# ✅ Downloaded: comfortable_in_sign_language
# ⚠️ Only one video for deep_in_sign_language, using fallback.
# ✅ Downloaded: deep_in_sign_language
# ⏩ Skipping already downloaded: doubt_in_sign_language
# ⏩ Skipping already downloaded: english_in_sign_language
# ⚠️ Only one video for signs_for_everyday, using fallback.
# ✅ Downloaded: signs_for_everyday
# ⚠️ Only one video for signs_for_everything, using fallback.
# ✅ Downloaded: signs_for_everything
# ⏩ Skipping already downloaded: example_in_sign_language
# ⏩ Skipping already downloaded: father_in_sign_language
# ⏩ Skipping already downloaded: funny_in_sign_language
# ⚠️ Only one video for asl_signs_for_game, using fallback.
# ✅ Downloaded: asl_signs_for_game
# ⏩ Skipping already downloaded: gift_in_sign_language
# ⏩ Skipping already downloaded: grow_in_sign_language
# ⚠️ Only one video for signs_for_guess, using fallback.
# ✅ Downloaded: signs_for_guess
# ⏩ Skipping already downloaded: hear_in_sign_language
# ⏩ Skipping already downloaded: hold_in_sign_language
# ⏩ Skipping already downloaded: house_in_sign_language
# ⏩ Skipping already downloaded: idea_in_sign_language
# ⏩ Skipping already downloaded: if_in_sign_language
# ⚠️ Only one video for important_in_sign_language, using fallback.
# ✅ Downloaded: important_in_sign_language
# ⚠️ Only one video for include_in_sign_language, using fallback.
# ✅ Downloaded: include_in_sign_language
# ⚠️ Only one video for signs_for_interpreter, using fallback.
# ✅ Downloaded: signs_for_interpreter
# ⏩ Skipping already downloaded: joke_in_sign_language
# ⏩ Skipping already downloaded: letter_in_sign_language
# ⚠️ Only one video for signs_for_life, using fallback.
# ✅ Downloaded: signs_for_life
# ⏩ Skipping already downloaded: signs_for_look_like
# ⏩ Skipping already downloaded: lose,_lost_in_sign_language
# ⏩ Skipping already downloaded: love_in_sign_language
# ⚠️ Only one video for money_in_sign_language, using fallback.
# ✅ Downloaded: money_in_sign_language
# ⏩ Skipping already downloaded: mother_in_sign_language
# ⏩ Skipping already downloaded: move_in_sign_language
# ⚠️ Only one video for movie_in_sign_language, using fallback.
# ✅ Downloaded: movie_in_sign_language
# ⚠️ Only one video for signs_for_normal, using fallback.
# ✅ Downloaded: signs_for_normal
# ⚠️ Only one video for number_in_sign_language, using fallback.
# ✅ Downloaded: number_in_sign_language
# ⚠️ Only one video for signs_for_offspring, using fallback.
# ✅ Downloaded: signs_for_offspring
# ⏩ Skipping already downloaded: outside_in_sign_language
# ⚠️ Only one video for signs_for_overlook, using fallback.
# ✅ Downloaded: signs_for_overlook
# ⏩ Skipping already downloaded: paper_in_sign_language
# ⏩ Skipping already downloaded: party_in_sign_language
# ⏩ Skipping already downloaded: pay_in_sign_language
# ⏩ Skipping already downloaded: pen_in_sign_language
# ⏩ Skipping already downloaded: picture_in_sign_language
# ⚠️ Only one video for play_in_sign_language, using fallback.
# ✅ Downloaded: play_in_sign_language
# ⚠️ Only one video for signs_for_problem, using fallback.
# ✅ Downloaded: signs_for_problem
# ⚠️ Only one video for room_in_sign_language, using fallback.
# ✅ Downloaded: room_in_sign_language
# ⚠️ Only one video for safe_in_sign_language, using fallback.
# ✅ Downloaded: safe_in_sign_language
# ⏩ Skipping already downloaded: sell_in_sign_language
# ⚠️ Only one video for signs_for_service, using fallback.
# ✅ Downloaded: signs_for_service
# ⚠️ Only one video for signs_for_share, using fallback.
# ✅ Downloaded: signs_for_share
# ⏩ Skipping already downloaded: sick_in_sign_language
# ⏩ Skipping already downloaded: since_in_sign_language
# ⏩ Skipping already downloaded: sister_in_sign_language
# ⚠️ Only one video for smart_in_sign_language, using fallback.
# ✅ Downloaded: smart_in_sign_language
# ⏩ Skipping already downloaded: signs_for_soon
# ⚠️ Only one video for spring_in_sign_language, using fallback.
# ✅ Downloaded: spring_in_sign_language
# ⏩ Skipping already downloaded: story_in_sign_language
# ⚠️ Only one video for struggle_in_sign_language, using fallback.
# ✅ Downloaded: struggle_in_sign_language
# ⏩ Skipping already downloaded: study_in_sign_language
# ⚠️ Only one video for summer_in_sign_language, using fallback.
# ✅ Downloaded: summer_in_sign_language
# ⏩ Skipping already downloaded: sure_in_sign_language
# ⏩ Skipping already downloaded: that_in_sign_language
# ⚠️ Only one video for travel_in_sign_language, using fallback.
# ✅ Downloaded: travel_in_sign_language
# ⏩ Skipping already downloaded: wash_in_sign_language
# ⚠️ Only one video for water_in_sign_language, using fallback.
# ✅ Downloaded: water_in_sign_language
# ⏩ Skipping already downloaded: week_in_sign_language
# ⚠️ Only one video for signs_for_weekend, using fallback.
# ✅ Downloaded: signs_for_weekend
# ⏩ Skipping already downloaded: winter_in_sign_language
# ⚠️ Only one video for wish_in_sign_language, using fallback.
# ✅ Downloaded: wish_in_sign_language
# ⏩ Skipping already downloaded: word_in_sign_language
# ⏩ Skipping already downloaded: signs_for_yet,_not_yet
# ⚠️ Only one video for young_in_sign_language, using fallback.
# ✅ Downloaded: young_in_sign_language
# ⏩ Skipping already downloaded: yourself_in_sign_language
# ⚠️ Only one video for mirror_in_sign_language, using fallback.
# ✅ Downloaded: mirror_in_sign_language
# ⚠️ Only one video for signs_for_april_fool, using fallback.
# ✅ Downloaded: signs_for_april_fool
# ⏩ Skipping already downloaded: tax_in_sign_language
# ⏩ Skipping already downloaded: easter_in_sign_language
# ⏩ Skipping already downloaded: signs_for_condone
# ⏩ Skipping already downloaded: welcome_in_sign_language
# ⏩ Skipping already downloaded: sentence_in_sign_language
# ⏩ Skipping already downloaded: context_in_sign_language

# %%
video_urls = [
    "https://www.handspeak.com/word/1496/",
    "https://www.handspeak.com/word/120/",
    "https://www.handspeak.com/word/1112/",
    "https://www.handspeak.com/word/1911/",
    "https://www.handspeak.com/word/926/",
]

headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/124.0.0.0 Safari/537.36"
}

for page_url in video_urls:
    try:
        res = requests.get(page_url, headers=headers)
        soup = BeautifulSoup(res.content, "html.parser")

        # Extract the word from the <h1> or <title> tag
        heading = soup.find("h1") or soup.find("title")
        word_name = heading.get_text(strip=True).lower().replace(" ", "_") if heading else "unknown"

        video_tag = soup.find("video")
        video_url = video_tag.get("src") if video_tag else None

        if not video_url:
            print(f"❌ No video found for {word_name} ({page_url})")
            continue

        video_url = urljoin(page_url, video_url)
        video_path = os.path.join(output_folder, f"{word_name}.mp4")

        video_headers = {
            "User-Agent": headers["User-Agent"],
            "Referer": page_url
        }

        video_res = requests.get(video_url, headers=video_headers, stream=True)
        if video_res.status_code == 200:
            with open(video_path, "wb") as f:
                for chunk in video_res.iter_content(chunk_size=8192):
                    f.write(chunk)
            print(f"✅ Downloaded: {word_name}")
        else:
            print(f"❌ Failed to download {word_name} (status code: {video_res.status_code})")

    except Exception as e:
        print(f"⚠️ Error downloading from {page_url}: {e}")
# Out:
# ⚠️ Error downloading from https://www.handspeak.com/word/1496/: [Errno 22] Invalid argument: 'asl_videos\\"no"_in_sign_language.mp4'
# ⚠️ Error downloading from https://www.handspeak.com/word/120/: [Errno 2] No such file or directory: 'asl_videos\\asl_/_american_sign_language_/_ameslan.mp4'
# ⚠️ Error downloading from https://www.handspeak.com/word/1112/: [Errno 22] Invalid argument: 'asl_videos\\"in"_in_sign_language.mp4'
# ⚠️ Error downloading from https://www.handspeak.com/word/1911/: [Errno 22] Invalid argument: 'asl_videos\\"see"_in_sign_language.mp4'
# ⚠️ Error downloading from https://www.handspeak.com/word/926/: [Errno 22] Invalid argument: 'asl_videos\\"good"_in_sign_language.mp4'

# %% [markdown]
# File Name Clean Up

# %%
import os
import re

# ← Update this to your actual folder path
folder = r"asl_videos"

# Compile regexes for both naming patterns
p1 = re.compile(r"^(?P<word>.+)_in_sign_language\.mp4$")
p2 = re.compile(r"^signs_for_(?P<word>.+)\.mp4$")

for fname in os.listdir(folder):
    # Skip anything that isn’t a .mp4
    if not fname.lower().endswith(".mp4"):
        continue

    new_name = None
    if m := p1.match(fname):
        new_name = f"{m.group('word')}.mp4"
    elif m := p2.match(fname):
        new_name = f"{m.group('word')}.mp4"

    # If it matched one of our patterns, rename it
    if new_name and new_name != fname:
        src = os.path.join(folder, fname)
        dst = os.path.join(folder, new_name)
        if os.path.exists(dst):
            print(f"⚠️ Destination exists, skipping: {dst}")
        else:
            os.rename(src, dst)
            print(f"✅ Renamed: {fname} → {new_name}")
# Out:
# ✅ Renamed: about_in_sign_language.mp4 → about.mp4
# ✅ Renamed: accept_in_sign_language.mp4 → accept.mp4
# ✅ Renamed: afternoon_in_sign_language.mp4 → afternoon.mp4
# ✅ Renamed: against_in_sign_language.mp4 → against.mp4
# ✅ Renamed: again_in_sign_language.mp4 → again.mp4
# ✅ Renamed: agree_in_sign_language.mp4 → agree.mp4
# ✅ Renamed: allow_in_sign_language.mp4 → allow.mp4
# ✅ Renamed: all_in_sign_language.mp4 → all.mp4
# ✅ Renamed: alone_in_sign_language.mp4 → alone.mp4
# ✅ Renamed: always_in_sign_language.mp4 → always.mp4
# ✅ Renamed: and_in_sign_language.mp4 → and.mp4
# ✅ Renamed: angry_in_sign_language.mp4 → angry.mp4
# ✅ Renamed: animal_in_sign_language.mp4 → animal.mp4
# ✅ Renamed: answer_in_sign_language.mp4 → answer.mp4
# ✅ Renamed: anything_in_sign_language.mp4 → anything.mp4
# ✅ Renamed: any_in_sign_language.mp4 → any.mp4
# ✅ Renamed: argue,_argument_in_sign_language.mp4 → argue,_argument.mp4
# ✅ Renamed: arrive_in_sign_language.mp4 → arrive.mp4
# ✅ Renamed: ask_in_sign_language.mp4 → ask.mp4
# ✅ Renamed: asl_in_sign_language.mp4 → asl.mp4
# ✅ Renamed: attitude_in_sign_language.mp4 → attitude.mp4
# ✅ Renamed: autumn_in_sign_language.mp4 → autumn.mp4
# ✅ Renamed: avoid_in_sign_language.mp4 → avoid.mp4
# ✅ Renamed: away_in_sign_language.mp4 → away.mp4
# ✅ Renamed: bad_in_sign_language.mp4 → bad.mp4
# ✅ Renamed: beautiful_in_sign_language.mp4 → beautiful.mp4
# ✅ Renamed: because_in_sign_language.mp4 → because.mp4
# ✅ Renamed: before_in_sign_language.mp4 → before.mp4
# ✅ Renamed: believe_in_sign_language.mp4 → believe.mp4
# ✅ Renamed: better_in_sign_language.mp4 → better.mp4
# ✅ Renamed: big_in_sign_language.mp4 → big.mp4
# ✅ Renamed: book_in_sign_language.mp4 → book.mp4
# ✅ Renamed: both_in_sign_language.mp4 → both.mp4
# ✅ Renamed: boy_in_sign_language.mp4 → boy.mp4
# ✅ Renamed: bring_in_sign_language.mp4 → bring.mp4
# ✅ Renamed: brother_in_sign_language.mp4 → brother.mp4
# ✅ Renamed: busy_in_sign_language.mp4 → busy.mp4
# ✅ Renamed: but_in_sign_language.mp4 → but.mp4
# ✅ Renamed: buy_in_sign_language.mp4 → buy.mp4
# ✅ Renamed: can_in_sign_language.mp4 → can.mp4
# ✅ Renamed: car_in_sign_language.mp4 → car.mp4
# ✅ Renamed: change_in_sign_language.mp4 → change.mp4
# ✅ Renamed: class_in_sign_language.mp4 → class.mp4
# ✅ Renamed: close_in_sign_language.mp4 → close.mp4
# ✅ Renamed: color_in_sign_language.mp4 → color.mp4
# ✅ Renamed: come_in_sign_language.mp4 → come.mp4
# ✅ Renamed: comfortable_in_sign_language.mp4 → comfortable.mp4
# ✅ Renamed: context_in_sign_language.mp4 → context.mp4
# ✅ Renamed: day_in_sign_language.mp4 → day.mp4
# ✅ Renamed: deaf_in_sign_language.mp4 → deaf.mp4
# ✅ Renamed: deep_in_sign_language.mp4 → deep.mp4
# ✅ Renamed: different_in_sign_language.mp4 → different.mp4
# ✅ Renamed: doubt_in_sign_language.mp4 → doubt.mp4
# ✅ Renamed: drink_in_sign_language.mp4 → drink.mp4
# ✅ Renamed: drive_in_sign_language.mp4 → drive.mp4
# ✅ Renamed: early_in_sign_language.mp4 → early.mp4
# ✅ Renamed: easter_in_sign_language.mp4 → easter.mp4
# ✅ Renamed: easy_in_sign_language.mp4 → easy.mp4
# ✅ Renamed: eat_in_sign_language.mp4 → eat.mp4
# ✅ Renamed: email_in_sign_language.mp4 → email.mp4
# ✅ Renamed: english_in_sign_language.mp4 → english.mp4
# ✅ Renamed: enough_in_sign_language.mp4 → enough.mp4
# ✅ Renamed: every_in_sign_language.mp4 → every.mp4
# ✅ Renamed: example_in_sign_language.mp4 → example.mp4
# ✅ Renamed: excuse_in_sign_language.mp4 → excuse.mp4
# ✅ Renamed: false_in_sign_language.mp4 → false.mp4
# ✅ Renamed: family_in_sign_language.mp4 → family.mp4
# ✅ Renamed: far_in_sign_language.mp4 → far.mp4
# ✅ Renamed: fast_in_sign_language.mp4 → fast.mp4
# ✅ Renamed: father_in_sign_language.mp4 → father.mp4
# ✅ Renamed: feel_in_sign_language.mp4 → feel.mp4
# ✅ Renamed: few_in_sign_language.mp4 → few.mp4
# ✅ Renamed: find_in_sign_language.mp4 → find.mp4
# ✅ Renamed: fine_in_sign_language.mp4 → fine.mp4
# ✅ Renamed: fingerspell_in_sign_language.mp4 → fingerspell.mp4
# ✅ Renamed: finish_in_sign_language.mp4 → finish.mp4
# ✅ Renamed: follow_in_sign_language.mp4 → follow.mp4
# ✅ Renamed: food_in_sign_language.mp4 → food.mp4
# ✅ Renamed: forget_in_sign_language.mp4 → forget.mp4
# ✅ Renamed: for_in_sign_language.mp4 → for.mp4
# ✅ Renamed: friend_in_sign_language.mp4 → friend.mp4
# ✅ Renamed: from_in_sign_language.mp4 → from.mp4
# ✅ Renamed: funny_in_sign_language.mp4 → funny.mp4
# ✅ Renamed: get_in_sign_language.mp4 → get.mp4
# ✅ Renamed: gift_in_sign_language.mp4 → gift.mp4
# ✅ Renamed: girl_in_sign_language.mp4 → girl.mp4
# ✅ Renamed: give_in_sign_language.mp4 → give.mp4
# ✅ Renamed: go,_went_in_sign_language.mp4 → go,_went.mp4
# ✅ Renamed: gone_in_sign_language.mp4 → gone.mp4
# ✅ Renamed: good_in_sign_language.mp4 → good.mp4
# ✅ Renamed: grow_in_sign_language.mp4 → grow.mp4
# ✅ Renamed: happen_in_sign_language.mp4 → happen.mp4
# ✅ Renamed: happy_in_sign_language.mp4 → happy.mp4
# ✅ Renamed: hard_in_sign_language.mp4 → hard.mp4
# ✅ Renamed: have,_has,_had_in_sign_language.mp4 → have,_has,_had.mp4
# ✅ Renamed: hearing_in_sign_language.mp4 → hearing.mp4
# ✅ Renamed: hear_in_sign_language.mp4 → hear.mp4
# ✅ Renamed: hello_in_sign_language.mp4 → hello.mp4
# ✅ Renamed: help_in_sign_language.mp4 → help.mp4
# ✅ Renamed: here_in_sign_language.mp4 → here.mp4
# ✅ Renamed: he_in_sign_language.mp4 → he.mp4
# ✅ Renamed: hold_in_sign_language.mp4 → hold.mp4
# ✅ Renamed: home_in_sign_language.mp4 → home.mp4
# ✅ Renamed: hot_in_sign_language.mp4 → hot.mp4
# ✅ Renamed: house_in_sign_language.mp4 → house.mp4
# ✅ Renamed: how_in_sign_language.mp4 → how.mp4
# ✅ Renamed: hurt_in_sign_language.mp4 → hurt.mp4
# ✅ Renamed: idea_in_sign_language.mp4 → idea.mp4
# ✅ Renamed: if_in_sign_language.mp4 → if.mp4
# ✅ Renamed: important_in_sign_language.mp4 → important.mp4
# ✅ Renamed: improve_in_sign_language.mp4 → improve.mp4
# ✅ Renamed: include_in_sign_language.mp4 → include.mp4
# ✅ Renamed: inform_in_sign_language.mp4 → inform.mp4
# ✅ Renamed: internet_in_sign_language.mp4 → internet.mp4
# ✅ Renamed: in_in_sign_language.mp4 → in.mp4
# ✅ Renamed: joke_in_sign_language.mp4 → joke.mp4
# ✅ Renamed: keep_in_sign_language.mp4 → keep.mp4
# ✅ Renamed: know_in_sign_language.mp4 → know.mp4
# ✅ Renamed: last_in_sign_language.mp4 → last.mp4
# ✅ Renamed: later_in_sign_language.mp4 → later.mp4
# ✅ Renamed: late_in_sign_language.mp4 → late.mp4
# ✅ Renamed: learn_in_sign_language.mp4 → learn.mp4
# ✅ Renamed: leave_in_sign_language.mp4 → leave.mp4
# ✅ Renamed: letter_in_sign_language.mp4 → letter.mp4
# ✅ Renamed: like_in_sign_language.mp4 → like.mp4
# ✅ Renamed: little_in_sign_language.mp4 → little.mp4
# ✅ Renamed: live_in_sign_language.mp4 → live.mp4
# ✅ Renamed: look_in_sign_language.mp4 → look.mp4
# ✅ Renamed: lose,_lost_in_sign_language.mp4 → lose,_lost.mp4
# ✅ Renamed: love_in_sign_language.mp4 → love.mp4
# ✅ Renamed: make_in_sign_language.mp4 → make.mp4
# ✅ Renamed: many_in_sign_language.mp4 → many.mp4
# ✅ Renamed: man_in_sign_language.mp4 → man.mp4
# ✅ Renamed: mean,_meaning_in_sign_language.mp4 → mean,_meaning.mp4
# ✅ Renamed: meet_in_sign_language.mp4 → meet.mp4
# ✅ Renamed: me_in_sign_language.mp4 → me.mp4
# ✅ Renamed: minute_in_sign_language.mp4 → minute.mp4
# ✅ Renamed: mirror_in_sign_language.mp4 → mirror.mp4
# ✅ Renamed: money_in_sign_language.mp4 → money.mp4
# ✅ Renamed: month_in_sign_language.mp4 → month.mp4
# ✅ Renamed: more_in_sign_language.mp4 → more.mp4
# ✅ Renamed: morning_in_sign_language.mp4 → morning.mp4
# ✅ Renamed: most_in_sign_language.mp4 → most.mp4
# ✅ Renamed: mother_in_sign_language.mp4 → mother.mp4
# ✅ Renamed: move_in_sign_language.mp4 → move.mp4
# ✅ Renamed: movie_in_sign_language.mp4 → movie.mp4
# ✅ Renamed: must_in_sign_language.mp4 → must.mp4
# ✅ Renamed: my_in_sign_language.mp4 → my.mp4
# ✅ Renamed: name_in_sign_language.mp4 → name.mp4
# ✅ Renamed: near_in_sign_language.mp4 → near.mp4
# ✅ Renamed: need_in_sign_language.mp4 → need.mp4
# ✅ Renamed: never_in_sign_language.mp4 → never.mp4
# ✅ Renamed: new_in_sign_language.mp4 → new.mp4
# ✅ Renamed: next_in_sign_language.mp4 → next.mp4
# ✅ Renamed: night_in_sign_language.mp4 → night.mp4
# ✅ Renamed: nothing_in_sign_language.mp4 → nothing.mp4
# ✅ Renamed: not_in_sign_language.mp4 → not.mp4
# ✅ Renamed: now_in_sign_language.mp4 → now.mp4
# ✅ Renamed: no_in_sign_language.mp4 → no.mp4
# ✅ Renamed: number_in_sign_language.mp4 → number.mp4
# ✅ Renamed: okay_in_sign_language.mp4 → okay.mp4
# ✅ Renamed: old_in_sign_language.mp4 → old.mp4
# ✅ Renamed: open_in_sign_language.mp4 → open.mp4
# ✅ Renamed: opposite_in_sign_language.mp4 → opposite.mp4
# ✅ Renamed: other,_another_in_sign_language.mp4 → other,_another.mp4
# ✅ Renamed: outside_in_sign_language.mp4 → outside.mp4
# ✅ Renamed: out_in_sign_language.mp4 → out.mp4
# ✅ Renamed: paper_in_sign_language.mp4 → paper.mp4
# ✅ Renamed: party_in_sign_language.mp4 → party.mp4
# ✅ Renamed: pay_in_sign_language.mp4 → pay.mp4
# ✅ Renamed: pen_in_sign_language.mp4 → pen.mp4
# ✅ Renamed: people_in_sign_language.mp4 → people.mp4
# ✅ Renamed: picture_in_sign_language.mp4 → picture.mp4
# ✅ Renamed: plan_in_sign_language.mp4 → plan.mp4
# ✅ Renamed: play_in_sign_language.mp4 → play.mp4
# ✅ Renamed: please_in_sign_language.mp4 → please.mp4
# ✅ Renamed: practice_in_sign_language.mp4 → practice.mp4
# ✅ Renamed: question_in_sign_language.mp4 → question.mp4
# ✅ Renamed: ready_in_sign_language.mp4 → ready.mp4
# ✅ Renamed: read_in_sign_language.mp4 → read.mp4
# ✅ Renamed: remember_in_sign_language.mp4 → remember.mp4
# ✅ Renamed: rest_in_sign_language.mp4 → rest.mp4
# ✅ Renamed: right_in_sign_language.mp4 → right.mp4
# ✅ Renamed: room_in_sign_language.mp4 → room.mp4
# ✅ Renamed: run_in_sign_language.mp4 → run.mp4
# ✅ Renamed: sad_in_sign_language.mp4 → sad.mp4
# ✅ Renamed: safe_in_sign_language.mp4 → safe.mp4
# ✅ Renamed: same_in_sign_language.mp4 → same.mp4
# ✅ Renamed: school_in_sign_language.mp4 → school.mp4
# ✅ Renamed: see_in_sign_language.mp4 → see.mp4
# ✅ Renamed: sell_in_sign_language.mp4 → sell.mp4
# ✅ Renamed: send_in_sign_language.mp4 → send.mp4
# ✅ Renamed: sentence_in_sign_language.mp4 → sentence.mp4
# ✅ Renamed: she_in_sign_language.mp4 → she.mp4
# ✅ Renamed: should_in_sign_language.mp4 → should.mp4
# ✅ Renamed: show_in_sign_language.mp4 → show.mp4
# ✅ Renamed: sick_in_sign_language.mp4 → sick.mp4
# ✅ Renamed: signs_for_almost.mp4 → almost.mp4
# ✅ Renamed: signs_for_april_fool.mp4 → april_fool.mp4
# ✅ Renamed: signs_for_average.mp4 → average.mp4
# ✅ Renamed: signs_for_basic.mp4 → basic.mp4
# ✅ Renamed: signs_for_best.mp4 → best.mp4
# ✅ Renamed: signs_for_calm.mp4 → calm.mp4
# ✅ Renamed: signs_for_close,_close-by,_close_to.mp4 → close,_close-by,_close_to.mp4
# ✅ Renamed: signs_for_cold.mp4 → cold.mp4
# ✅ Renamed: signs_for_condone.mp4 → condone.mp4
# ✅ Renamed: signs_for_everyday.mp4 → everyday.mp4
# ✅ Renamed: signs_for_everything.mp4 → everything.mp4
# ✅ Renamed: signs_for_guess.mp4 → guess.mp4
# ✅ Renamed: signs_for_interpreter.mp4 → interpreter.mp4
# ✅ Renamed: signs_for_life.mp4 → life.mp4
# ✅ Renamed: signs_for_look_for.mp4 → look_for.mp4
# ✅ Renamed: signs_for_look_like.mp4 → look_like.mp4
# ✅ Renamed: signs_for_lot,_a_lot.mp4 → lot,_a_lot.mp4
# ✅ Renamed: signs_for_normal.mp4 → normal.mp4
# ✅ Renamed: signs_for_offspring.mp4 → offspring.mp4
# ✅ Renamed: signs_for_only.mp4 → only.mp4
# ✅ Renamed: signs_for_overlook.mp4 → overlook.mp4
# ✅ Renamed: signs_for_prefer.mp4 → prefer.mp4
# ✅ Renamed: signs_for_problem.mp4 → problem.mp4
# ✅ Renamed: signs_for_say.mp4 → say.mp4
# ✅ Renamed: signs_for_service.mp4 → service.mp4
# ✅ Renamed: signs_for_share.mp4 → share.mp4
# ✅ Renamed: signs_for_soon.mp4 → soon.mp4
# ✅ Renamed: signs_for_store.mp4 → store.mp4
# ✅ Renamed: signs_for_than.mp4 → than.mp4
# ✅ Renamed: signs_for_their.mp4 → their.mp4
# ✅ Renamed: signs_for_weekend.mp4 → weekend.mp4
# ✅ Renamed: signs_for_yet,_not_yet.mp4 → yet,_not_yet.mp4
# ✅ Renamed: sign_(word)_in_sign_language.mp4 → sign_(word).mp4
# ✅ Renamed: since_in_sign_language.mp4 → since.mp4
# ✅ Renamed: sister_in_sign_language.mp4 → sister.mp4
# ✅ Renamed: sit_in_sign_language.mp4 → sit.mp4
# ✅ Renamed: sleep_in_sign_language.mp4 → sleep.mp4
# ✅ Renamed: slow_in_sign_language.mp4 → slow.mp4
# ✅ Renamed: small_in_sign_language.mp4 → small.mp4
# ✅ Renamed: smart_in_sign_language.mp4 → smart.mp4
# ✅ Renamed: something_in_sign_language.mp4 → something.mp4
# ✅ Renamed: sometimes_in_sign_language.mp4 → sometimes.mp4
# ✅ Renamed: some_in_sign_language.mp4 → some.mp4
# ✅ Renamed: sorry_in_sign_language.mp4 → sorry.mp4
# ✅ Renamed: spring_in_sign_language.mp4 → spring.mp4
# ✅ Renamed: start_in_sign_language.mp4 → start.mp4
# ✅ Renamed: stay_in_sign_language.mp4 → stay.mp4
# ✅ Renamed: still_in_sign_language.mp4 → still.mp4
# ✅ Renamed: stop_in_sign_language.mp4 → stop.mp4
# ✅ Renamed: story_in_sign_language.mp4 → story.mp4
# ✅ Renamed: struggle_in_sign_language.mp4 → struggle.mp4
# ✅ Renamed: study_in_sign_language.mp4 → study.mp4
# ✅ Renamed: summer_in_sign_language.mp4 → summer.mp4
# ✅ Renamed: support_in_sign_language.mp4 → support.mp4
# ✅ Renamed: sure_in_sign_language.mp4 → sure.mp4
# ✅ Renamed: take_in_sign_language.mp4 → take.mp4
# ✅ Renamed: talk_in_sign_language.mp4 → talk.mp4
# ✅ Renamed: tax_in_sign_language.mp4 → tax.mp4
# ✅ Renamed: teach_in_sign_language.mp4 → teach.mp4
# ✅ Renamed: tell_in_sign_language.mp4 → tell.mp4
# ✅ Renamed: thank_you_in_sign_language.mp4 → thank_you.mp4
# ✅ Renamed: that_in_sign_language.mp4 → that.mp4
# ✅ Renamed: they_in_sign_language.mp4 → they.mp4
# ✅ Renamed: thing_in_sign_language.mp4 → thing.mp4
# ✅ Renamed: think_in_sign_language.mp4 → think.mp4
# ✅ Renamed: time_in_sign_language.mp4 → time.mp4
# ✅ Renamed: tired_in_sign_language.mp4 → tired.mp4
# ✅ Renamed: today_in_sign_language.mp4 → today.mp4
# ✅ Renamed: toilet_in_sign_language.mp4 → toilet.mp4
# ✅ Renamed: tomorrow_in_sign_language.mp4 → tomorrow.mp4
# ✅ Renamed: travel_in_sign_language.mp4 → travel.mp4
# ✅ Renamed: true_in_sign_language.mp4 → true.mp4
# ✅ Renamed: try_in_sign_language.mp4 → try.mp4
# ✅ Renamed: understand_in_sign_language.mp4 → understand.mp4
# ✅ Renamed: until_in_sign_language.mp4 → until.mp4
# ✅ Renamed: use_in_sign_language.mp4 → use.mp4
# ✅ Renamed: visit_in_sign_language.mp4 → visit.mp4
# ✅ Renamed: wait_in_sign_language.mp4 → wait.mp4
# ✅ Renamed: walk_in_sign_language.mp4 → walk.mp4
# ✅ Renamed: want_in_sign_language.mp4 → want.mp4
# ✅ Renamed: warm_in_sign_language.mp4 → warm.mp4
# ✅ Renamed: wash_in_sign_language.mp4 → wash.mp4
# ✅ Renamed: watch_in_sign_language.mp4 → watch.mp4
# ✅ Renamed: water_in_sign_language.mp4 → water.mp4
# ✅ Renamed: week_in_sign_language.mp4 → week.mp4
# ✅ Renamed: welcome_in_sign_language.mp4 → welcome.mp4
# ✅ Renamed: what_in_sign_language.mp4 → what.mp4
# ✅ Renamed: when_in_sign_language.mp4 → when.mp4
# ✅ Renamed: where_in_sign_language.mp4 → where.mp4
# ✅ Renamed: which_in_sign_language.mp4 → which.mp4
# ✅ Renamed: who_in_sign_language.mp4 → who.mp4
# ✅ Renamed: why_in_sign_language.mp4 → why.mp4
# ✅ Renamed: will_in_sign_language.mp4 → will.mp4
# ✅ Renamed: winter_in_sign_language.mp4 → winter.mp4
# ✅ Renamed: wish_in_sign_language.mp4 → wish.mp4
# ✅ Renamed: with_in_sign_language.mp4 → with.mp4
# ✅ Renamed: woman_in_sign_language.mp4 → woman.mp4
# ✅ Renamed: word_in_sign_language.mp4 → word.mp4
# ✅ Renamed: work_in_sign_language.mp4 → work.mp4
# ✅ Renamed: worse_in_sign_language.mp4 → worse.mp4
# ✅ Renamed: write_in_sign_language.mp4 → write.mp4
# ✅ Renamed: wrong_in_sign_language.mp4 → wrong.mp4
# ✅ Renamed: yesterday_in_sign_language.mp4 → yesterday.mp4
# ✅ Renamed: yes_in_sign_language.mp4 → yes.mp4
# ✅ Renamed: young_in_sign_language.mp4 → young.mp4
# ✅ Renamed: yourself_in_sign_language.mp4 → yourself.mp4
# ✅ Renamed: your_in_sign_language.mp4 → your.mp4
# ✅ Renamed: you_in_sign_language.mp4 → you.mp4
